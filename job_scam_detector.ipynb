# %% [markdown]
# <a href="https://colab.research.google.com/github/muski2504/Job_scam_detector/blob/main/job_scam_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b18c296-a4ad-4a1f-a610-9e2dc82b271f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b18c296-a4ad-4a1f-a610-9e2dc82b271f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/scam_posts_v2.csv")
df.head()
# Out:
#                                                 text  is_scam  trust_score  \
# 0  Remote Software Engineer position at Infosys. ...        0            9
# 1  Subject: Job Offer from IBM India\nDear Candid...        1            0
# 2  Home-based packing jobs available in your area...        1            1
# 3  Remote Java Developer position at Capgemini. S...        0            9
# 4  🔴 URGENT! CRED hiring WFH staff. Salary ₹60,00...        1            0
#
#      source      salary_mentioned  has_personal_email  urgency_words  \
# 0  linkedin               6-9 LPA               False          False
# 1     email  ₹25,000-40,000/month                True          False
# 2  whatsapp      ₹1,200-2,000/day               False          False
# 3  linkedin               6-9 LPA               False          False
# 4  whatsapp  ₹40,000-60,000/month               False           True
#
#                                               reason
# ...
